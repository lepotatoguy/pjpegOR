# %%
import numpy as np
import pandas as pd
from matplotlib import rcParams
from matplotlib import pyplot as plt
plt.rcParams["font.family"] = "Times New Roman"

# %%
data = pd.read_csv('data_desktop.csv')

# %%
data
# Out:
#    Picture  color.jpg  color_p_img1_1.jpg  color_p_img2_1.jpg  \
# 0   10.000      0.657               0.070               0.069
# 1    5.000      1.160               0.080               0.078
# 2    3.000      1.890               0.084               0.095
# 3    1.000      5.550               0.149               0.170
# 4    0.500     11.050               0.227               0.272
# 5    0.250     22.010               0.381               0.447
# 6    0.125     43.940               0.666               0.847
#
#    color_p_img3_1.jpg  color_p_img4_1.jpg  color_p_img5_1.jpg  \
# 0               0.077               0.177               0.101
# 1               0.085               0.183               0.120
# 2               0.104               0.205               0.161
# 3               0.204               0.255               0.355
# 4               0.347               0.430               0.659
# 5               0.601               0.821               1.250
# 6               1.200               1.580               2.410
#
#    color_p_img6_1.jpg  color_p_img7_1.jpg  color_p_img8_1.jpg  ...  \
# 0               0.087               0.128               0.135  ...
# 1               0.121               0.139               0.139  ...
# 2               0.159               0.177               0.206  ...
# 3               0.343               0.406               0.444  ...
# 4               0.654               0.740               0.865  ...
# 5               1.170               1.460               1.640  ...
# 6               2.350               2.770               3.180  ...
#
#    image5_p_img7_1.jpg  image5_p_img8_1.jpg  map_p_img1_1.jpg  \
# 0                 1.07                 1.29             0.664
# 1                 2.06                 2.51             1.360
# 2                 3.42                 4.14             2.060
# 3                10.07                12.28             6.090
# 4                20.08                24.51            12.100
# 5                40.15                48.97            24.120
# 6                78.00                96.00            48.200
#
#    map_p_img2_1.jpg  map_p_img3_1.jpg  map_p_img4_1.jpg  map_p_img5_1.jpg  \
# 0             0.836             0.899              1.11              2.02
# 1             1.380             1.570              1.90              3.50
# 2             2.250             2.590              3.11              5.80
# 3             6.620             7.600              9.25             17.29
# 4            13.210            15.150             18.41             34.50
# 5            26.340            30.230             36.77             66.00
# 6            52.610            60.000             72.00            138.00
#
#    map_p_img6_1.jpg  map_p_img7_1.jpg  map_p_img8_1.jpg
# 0              1.80              2.27              2.53
# 1              3.14              4.04              4.99
# 2              5.18              6.68              8.27
# 3             15.41             19.91             24.68
# 4             30.78             39.76             49.31
# 5             60.00             78.00             96.00
# 6            126.00            162.00            198.00
#
# [7 rows x 45 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
#pic1 = data[data['Picture'].str.contains("color")]
pic1 = data[['Picture','color.jpg','color_p_img1_1.jpg','color_p_img2_1.jpg','color_p_img3_1.jpg','color_p_img4_1.jpg',
            'color_p_img5_1.jpg','color_p_img6_1.jpg','color_p_img7_1.jpg','color_p_img8_1.jpg',]]

# %%
pic1
# Out:
#    Picture  color.jpg  color_p_img1_1.jpg  color_p_img2_1.jpg  \
# 0   10.000      0.657               0.070               0.069
# 1    5.000      1.160               0.080               0.078
# 2    3.000      1.890               0.084               0.095
# 3    1.000      5.550               0.149               0.170
# 4    0.500     11.050               0.227               0.272
# 5    0.250     22.010               0.381               0.447
# 6    0.125     43.940               0.666               0.847
#
#    color_p_img3_1.jpg  color_p_img4_1.jpg  color_p_img5_1.jpg  \
# 0               0.077               0.177               0.101
# 1               0.085               0.183               0.120
# 2               0.104               0.205               0.161
# 3               0.204               0.255               0.355
# 4               0.347               0.430               0.659
# 5               0.601               0.821               1.250
# 6               1.200               1.580               2.410
#
#    color_p_img6_1.jpg  color_p_img7_1.jpg  color_p_img8_1.jpg
# 0               0.087               0.128               0.135
# 1               0.121               0.139               0.139
# 2               0.159               0.177               0.206
# 3               0.343               0.406               0.444
# 4               0.654               0.740               0.865
# 5               1.170               1.460               1.640
# 6               2.350               2.770               3.180

# %%
plt.plot(pic1['Picture'],pic1['color.jpg'])
plt.xlabel("Mbps")
plt.ylabel("seconds")
#plt.legend(["For main picture", "For scan 1"])
plt.gca().invert_xaxis()

# %%
plt.plot(pic1['Picture'],pic1['color.jpg'])
plt.plot(pic1['Picture'],pic1['color_p_img1_1.jpg'])
plt.xlabel("Mbps")
plt.ylabel("seconds")
plt.legend(["For main picture", "For scan 1"])
plt.gca().invert_xaxis()

# %%
plt.plot(pic1['Picture'],pic1['color_p_img1_1.jpg'])
plt.plot(pic1['Picture'],pic1['color_p_img2_1.jpg'])
plt.plot(pic1['Picture'],pic1['color_p_img3_1.jpg'])
plt.plot(pic1['Picture'],pic1['color_p_img4_1.jpg'])
plt.plot(pic1['Picture'],pic1['color_p_img5_1.jpg'])
plt.plot(pic1['Picture'],pic1['color_p_img6_1.jpg'])
plt.plot(pic1['Picture'],pic1['color_p_img7_1.jpg'])
plt.plot(pic1['Picture'],pic1['color_p_img8_1.jpg'])
plt.xlabel("Mbps (picture-1 'color.jpg')")
plt.ylabel("seconds")
plt.legend(["For scan 1", "For scan 2", "For scan 3", "For scan 4", "For scan 5", "For scan 6", "For scan 7", "For scan 8",])
plt.gca().invert_xaxis()

# %%
x_indexes = np.arange(len(pic1['Picture']))
width = 0.1
plt.bar(x_indexes-(width*3),pic1['color_p_img1_1.jpg'],width=width)
plt.bar(x_indexes-(width*2),pic1['color_p_img2_1.jpg'],width=width)
plt.bar(x_indexes-width,pic1['color_p_img3_1.jpg'],width=width)
plt.bar(x_indexes,pic1['color_p_img4_1.jpg'],width=width)
plt.bar(x_indexes+width,pic1['color_p_img5_1.jpg'],width=width)
plt.bar(x_indexes+(width*2),pic1['color_p_img6_1.jpg'],width=width)
plt.bar(x_indexes+(width*3),pic1['color_p_img7_1.jpg'],width=width)
plt.bar(x_indexes+(width*4),pic1['color_p_img8_1.jpg'],width=width)

plt.xticks(ticks=x_indexes, labels= pic1['Picture'])

plt.title("Scan 1,2,3 Comparison")
plt.xlabel("Mbps (picture-1 'color.jpg')")
plt.ylabel("seconds")
#plt.legend(["For scan 1", "For scan 2", "For scan 3", "For scan 4", "For scan 5", "For scan 6", "For scan 7", "For scan 8",])
plt.legend(["Ss1Sc1", "Ss2Sc1", "Ss3Sc1","Ss4Sc1", "Ss5Sc1", "Ss6Sc1","Ss7Sc1", "Ss8Sc1"])

# %%
###For Mobile

# %%
data = pd.read_csv('data_mobile.csv')

# %%
pic1 = data[['Picture','color.jpg','color_p_img1_1.jpg','color_p_img2_1.jpg','color_p_img3_1.jpg','color_p_img4_1.jpg',
            'color_p_img5_1.jpg','color_p_img6_1.jpg','color_p_img7_1.jpg','color_p_img8_1.jpg',]]

# %%
pic1
# Out:
#               Picture  color.jpg  color_p_img1_1.jpg  color_p_img2_1.jpg  \
# 0     10Mbps (second)      0.745               0.103               0.095
# 1      5Mbps (second)      1.180               0.108               0.100
# 2      3Mbps (second)      1.930               0.120               0.112
# 3      1Mbps (second)      5.630               0.155               0.274
# 4    0.5Mbps (second)     11.190               0.312               0.304
# 5   0.25Mbps (second)     22.070               0.400               0.565
# 6  0.125Mbps (second)     44.120               0.753               0.872
#
#    color_p_img3_1.jpg  color_p_img4_1.jpg  color_p_img5_1.jpg  \
# 0               0.097               0.169               0.105
# 1               0.167               0.179               0.174
# 2               0.207               0.191               0.236
# 3               0.350               0.248               0.647
# 4               0.365               0.440               0.777
# 5               0.604               0.915               1.280
# 6               1.180               1.630               2.450
#
#    color_p_img6_1.jpg  color_p_img7_1.jpg  color_p_img8_1.jpg
# 0               0.115               0.282               0.289
# 1               0.140               0.273               0.266
# 2               0.169               0.288               0.659
# 3               0.353               0.557               0.495
# 4               1.010               0.862               0.999
# 5               1.270               1.550               1.640
# 6               2.340               2.900               3.210
